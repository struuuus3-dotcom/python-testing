# %% [markdown]
# ![image.png](attachment:8c7585b5-b606-4c99-ae37-40a52eedc678.png)

# %% [markdown]
# by **Gerard Meszaros**
#
# 2007

# %% [markdown]
# Zestaw wzorców stosowanych przy testowaniu oprogramowania. Wzorce mają ogólny charakter i nie są omawiane w kontekście jednego frameworka czy języka. Podstawy teorii testowania. "Filozofia testowania".

# %% [markdown]
# ## Omówimy kilka ważniejszych wzorców, żeby :
#
# 1. **[Fresh Fixture](01_fresh_fixture.ipynb)** - Nowa instancja dla każdego testu
# 2. **[Shared Fixture](02_shared_fixture.ipynb)** - Współdzielone dane między testami
# 3. **[Four-Phase Test](03_four_phase_test.ipynb)** - Setup/Exercise/Verify/Teardown
# 4. **[Test Doubles](04_test_doubles.ipynb)** - Mock, Stub, Spy, Fake, Dummy
# 5. **[State vs Behavior](05_state_vs_behavior.ipynb)** - Co sprawdzać w testach
